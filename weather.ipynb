# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_excel("data/weather_data.xls")
weather.head(10)
# Out:
#   Local time in Cape Town / Molteno Reservoir     T     Po   P   Pa   U  \
# 0                            22.07.2020 11:00  18.6  758.1 NaN  0.2  64
# 1                            22.07.2020 08:00  12.2  757.9 NaN  0.6  76
# 2                            22.07.2020 05:00  12.4  757.3 NaN -0.6  75
# 3                            22.07.2020 02:00  12.0  757.9 NaN -0.5  77
# 4                            21.07.2020 23:00  13.6  758.4 NaN  1.5  78
# 5                            21.07.2020 20:00  14.7  756.9 NaN  1.1  51
# 6                            21.07.2020 17:00  17.2  755.8 NaN  0.0  75
# 7                            21.07.2020 14:00  18.6  755.8 NaN -0.3  61
# 8                            21.07.2020 11:00  20.2  756.1 NaN  1.0  41
# 9                            21.07.2020 08:00  18.6  755.1 NaN  1.7  29
#
#                                       DD  Ff  ff10  ff3  ...  Cm  Ch  VV  \
# 0  Wind blowing from the north-northeast   1   2.0  NaN  ... NaN NaN NaN
# ...

# %%
# date time, wind intensity (categorical), precipitation (y/n)

# %%
new_weather = weather.drop("ff3", "Nh", "H", "P","VV", "Ff", "N", "Cl", "Cm", "Ch", "RRR", "tR",
              "WW", "W1", "W2", "E", "Tg", "E'", "sss", axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-88cebd3bb55a> in <module>
#       1 new_weather = weather.drop("ff3", "Nh", "H", "P","VV", "Ff", "N", "Cl", "Cm", "Ch", "RRR", "tR",
# ----> 2               "WW", "W1", "W2", "E", "Tg", "E'", "sss", axis=1)
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
new_weather.head()
# Out:
#   Local time in Cape Town / Molteno Reservoir     T     Po   Pa   U  \
# 0                            22.07.2020 11:00  18.6  758.1  0.2  64
# 1                            22.07.2020 08:00  12.2  757.9  0.6  76
# 2                            22.07.2020 05:00  12.4  757.3 -0.6  75
# 3                            22.07.2020 02:00  12.0  757.9 -0.5  77
# 4                            21.07.2020 23:00  13.6  758.4  1.5  78
#
#                                       DD  ff10    Tn    Tx    Td
# 0  Wind blowing from the north-northeast   2.0  11.5   NaN  11.7
# 1                          Calm, no wind   NaN  11.5   NaN   8.1
# 2                          Calm, no wind   NaN   NaN   NaN   8.1
# 3                          Calm, no wind   NaN   NaN   NaN   8.1
# 4       Wind blowing from the south-east   1.0   NaN  20.7   9.8

# %%
# Out:
# Index(['Local time in Cape Town / Molteno Reservoir', 'T', 'Po', 'P', 'Pa',
#        'U', 'DD', 'Ff', 'ff10', 'ff3', 'N', 'WW', 'W1', 'W2', 'Tn', 'Tx', 'Cl',
#        'Nh', 'H', 'Cm', 'Ch', 'VV', 'Td', 'RRR', 'tR', 'E', 'Tg', 'E'', 'sss'],
#       dtype='object')

# %%
new_weather.rename(columns={"T": "air temperature", "P": "stmospheric pressure", "U": "relative humidity",
                   "DD": "wind direction", "ff10": "maximum gust value", "Tn":"minimum air temperature",
                   "Tx":"maximum air temperature"}, inplace=True)
new_weather.head()
# Out:
#   Local time in Cape Town / Molteno Reservoir  air temperature     Po   Pa  \
# 0                            22.07.2020 11:00             18.6  758.1  0.2
# 1                            22.07.2020 08:00             12.2  757.9  0.6
# 2                            22.07.2020 05:00             12.4  757.3 -0.6
# 3                            22.07.2020 02:00             12.0  757.9 -0.5
# 4                            21.07.2020 23:00             13.6  758.4  1.5
#
#    relative humidity                         wind direction  \
# 0                 64  Wind blowing from the north-northeast
# 1                 76                          Calm, no wind
# 2                 75                          Calm, no wind
# 3                 77                          Calm, no wind
# 4                 78       Wind blowing from the south-east
#
#    maximum gust value  minimum air temperature  maximum air temperature    Td
# ...

# %%
new_weather.to_csv("data/weather_new.csv", index=False)
